# %%
api_key = "INSERT API KEY"

# %%
from google import genai
#Stage 1
client = genai.Client(api_key=api_key)

PREAMBLE = "Your goal is to identify ambiguity in problem statements."
LAST = "For each ambiguity, quote the unclear term, explain why it matters, and suggest a clarifying question"

response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Identify the ambiguities in the following problem:
    How should an organization decide whether and how to use AI?""",LAST]
)

print(response.text)
stage1response = response.text
# Out:
# The problem statement **"How should an organization decide whether and how to use AI?"** is high-level and contains several strategic ambiguities that would make it difficult to provide a concrete answer without further refinement.
#
# Here are the identified ambiguities:
#
# ### 1. "Organization"
# *   **Why it matters:** The decision-making process for a Fortune 500 tech company is vastly different from that of a small non-profit, a government agency, or a highly regulated healthcare provider. Each has different risk tolerances, budgets, technical capabilities, and ethical obligations.
# *   **Clarifying Question:** What is the size, industry, and regulatory environment of the organization in question?
#
# ### 2. "AI"
# *   **Why it matters:** "AI" is a broad umbrella term. Deciding to use Generative AI (like LLMs for writing emails) involves different risks and costs than deciding to use Predictive AI (like machine learning for credit scoring) or Physical AI (like robotics in a warehouse). The "how" and "whether" depend heavily on the specific technology.
# *   **Clarifying Question:** Which specific types of AI technology are being considered (e.g., Generative AI, predictive analytics, computer vision, or autonomous systems)?
#
# ### 3. "Decide"
# *   **Why it matters:** It is unclear what the primary drivers or constraints for the decision are. Is the organization deciding based on financial Return on Investment (ROI), competitive pressure ("everyone else is doing it"), ethical alignment, or operational efficiency?
# *   **Clarifying Question:** What are the primary KPIs or values (e.g., cost reduction, revenue growth, ethical safety, or brand reputation) that will define a "successful" decision?
#
# ### 4. "Use"
# *   **Why it matters:** "Using" AI can range from internal productivity (employees using ChatGPT) to embedding AI into a core product sold to customers. It could also mean "buying" an off-the-shelf solution versus "building" a proprietary model. Each path requires a different decision-making framework.
# *   **Clarifying Question:** Does "use" refer to internal operational improvements, external customer-facing products, or the development of proprietary AI models?
#
# ### 5. "How" (to use)
# *   **Why it matters:** This could refer to the **technical implementation** (the architecture and data stack), the **governance** (policies and ethics), or the **change management** (training staff and restructuring roles). Without narrowing this, the scope of the problem is potentially infinite.
# *   **Clarifying Question:** Does "how to use" refer to the technical deployment strategy, the ethical governance framework, or the organizational change management plan?

# %%
#Stage 2
client = genai.Client(api_key=api_key)

PREAMBLE = """Your goal is to use given identified ambiguity generate assumptions.
              Here is the current problem statement: How should an organization decide
              whether and how to use AI?"""
LAST = """For each assumption, state it clearly, explain why it is reasonable,
          and describe what changes if it is false"""

response2 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , "Identify assumptions given the following ambiguity found: ",stage1response,LAST]
)

print(response2.text)
stage2response = response2.text
# Out:
# To provide a concrete answer to the problem statement **"How should an organization decide whether and how to use AI?"**, we must narrow the scope by making specific assumptions based on the identified ambiguities.
#
# Below are the assumptions for each category:
#
# ---
#
# ### 1. Assumption regarding "Organization"
# *   **Assumption:** The organization is a **mid-to-large-sized commercial enterprise** operating in a **moderately regulated industry** (e.g., retail, manufacturing, or professional services).
# *   **Why it is reasonable:** This represents the "standard" corporate environment where there is enough capital to invest in AI, but also enough existing structure and risk to require a formal decision-making framework. It avoids the extremes of a resource-strapped three-person startup or a highly restricted government defense agency.
# *   **What changes if false:** If the organization is a **small startup**, the decision-making process becomes much faster, less formal, and driven by survival/growth rather than risk mitigation. If it is a **highly regulated entity** (e.g., a hospital), the "whether" to use AI would be dictated almost entirely by compliance and patient safety rather than profit.
#
# ### 2. Assumption regarding "AI"
# *   **Assumption:** "AI" refers primarily to **Generative AI (LLMs)** for text/content and **Predictive Analytics** for business forecasting.
# *   **Why it is reasonable:** These are currently the most accessible and sought-after forms of AI for general business applications. Most organizations asking this question are looking at how to leverage tools like ChatGPT or how to better use their existing data to predict customer behavior.
# *   **What changes if false:** If the AI in question is **Physical AI (Robotics)**, the decision shifts from software and data concerns to capital expenditures, physical workspace safety, and hardware maintenance. If it is **Autonomous Systems** (like self-driving vehicles), the ethical and legal liability becomes the primary factor in the "whether" decision.
#
# ### 3. Assumption regarding "Decide"
# *   **Assumption:** The primary driver for the decision is **measurable ROI (Return on Investment)** balanced against **Data Security risks.**
# *   **Why it is reasonable:** Most commercial organizations prioritize financial sustainability. A decision to adopt technology is rarely made without a business case that proves it will either save money (efficiency) or make money (revenue), provided it doesn't leak proprietary data.
# *   **What changes if false:** If the driver is **Competitive Parity (FOMO)**, the organization might skip the ROI analysis and decide to use AI simply because their competitors are doing so. If the driver is **Research & Development**, the organization may decide to use AI even if it loses money in the short term, viewing it as a long-term learning investment.
#
# ### 4. Assumption regarding "Use"
# *   **Assumption:** "Use" refers to the **procurement and integration of third-party tools** (the "Buy" or "Partner" model) for **internal operations.**
# *   **Why it is reasonable:** Building proprietary AI models from scratch is prohibitively expensive for most organizations. Most companies begin their AI journey by using existing software-as-a-service (SaaS) AI tools to improve internal workflows (e.g., HR, coding assistants, or customer support).
# *   **What changes if false:** If "Use" means **building a proprietary AI product to sell to customers**, the decision-making process must include market analysis, product-market fit, and long-term technical debt management, which are irrelevant for internal-only tools.
#
# ### 5. Assumption regarding "How" (to use)
# *   **Assumption:** "How" refers to the **Governance and Policy framework** (setting rules for employees and data usage).
# *   **Why it is reasonable:** For a modern organization, the biggest hurdle to "how" they use AI is not the technical installation, but the creation of an "Acceptable Use Policy" that protects the company from legal and ethical fallout.
# *   **What changes if false:** If "How" refers to **Technical Implementation (Architecture)**, the decision-making focus shifts to IT infrastructure, cloud computing costs, and the specific data engineering pipeline required to feed the AI. The conversation becomes a "tech stack" discussion rather than a "management" discussion.

# %%
#Stage 3
client = genai.Client(api_key=api_key)

PREAMBLE = """You are an expert in problem decomposition. Given the problem and assumptions below,
              produce a decomposition that would apply to THIS problem."""
problem = "How should an organization decide whether and how to use AI?"

response3 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """First, provide 5 domains which cover the problem.
                              For each domain, define the objective, identify evaluation criteria,
                              identify stakeholders, and identify dependencies""",problem,stage2response]
)

print(response3.text)
stage3response = response3.text
# Out:
# Based on your problem statement and the specific assumptions provided (mid-to-large enterprise, GenAI/Predictive focus, ROI vs. Security driver, "Buy" model, and Governance-heavy implementation), here is the decomposition across five key domains.
#
# ---
#
# ### 1. Strategic & Financial Viability
# **Objective:** To determine if the proposed AI solution aligns with corporate objectives and provides a justifiable return on investment (ROI) compared to alternative investments.
# *   **Evaluation Criteria:** Estimated Net Present Value (NPV), payback period (time to ROI), degree of alignment with annual business KPIs (e.g., % reduction in operational overhead), and cost-of-inaction (competitive risk).
# *   **Stakeholders:** Chief Financial Officer (CFO), Chief Executive Officer (CEO), Strategy Department, Business Unit Leaders.
# *   **Dependencies:** Accurate pricing models from third-party SaaS vendors; baseline data on current manual process costs.
#
# ### 2. Risk, Legal, & Compliance
# **Objective:** To identify and mitigate legal liabilities and security vulnerabilities associated with third-party AI procurement and data handling.
# *   **Evaluation Criteria:** Compliance with industry-specific regulations (e.g., GDPR, CCPA, or manufacturing safety standards), robustness of vendor data-processing agreements (DPAs), and Cybersecurity Maturity Model scores for the tool.
# *   **Stakeholders:** Chief Information Security Officer (CISO), General Counsel/Legal Team, Data Privacy Officer (DPO), Regulatory Compliance Officers.
# *   **Dependencies:** Finalized vendor security disclosures; clarity on emerging AI-specific legislation in the organization’s operating regions.
#
# ### 3. Technical Integration & Data Architecture
# **Objective:** To assess the feasibility of plugging third-party AI tools into the existing "tech stack" and ensuring the organization's data can effectively feed these systems.
# *   **Evaluation Criteria:** API compatibility with existing ERP/CRM systems, data quality and "cleanliness" scores, system latency, and scalability of the vendor’s cloud infrastructure.
# *   **Stakeholders:** Chief Technology Officer (CTO), IT Infrastructure Managers, Data Engineers, Solution Architects.
# *   **Dependencies:** Access to high-quality internal historical data (for predictive analytics); availability of IT resources for integration work.
#
# ### 4. Governance & Policy Framework
# **Objective:** To establish the rules of engagement for "how" the organization uses AI, ensuring ethical use and the protection of intellectual property.
# *   **Evaluation Criteria:** Completeness of the "Acceptable Use Policy" (AUP), presence of "Human-in-the-Loop" (HITL) requirements for high-stakes decisions, and the frequency of internal usage audits.
# *   **Stakeholders:** Chief Data Officer (CDO), AI Ethics Committee (or Task Force), Internal Audit, HR Leadership.
# *   **Dependencies:** Executive buy-in on corporate risk appetite; technical ability to monitor employee interactions with third-party LLMs.
#
# ### 5. Operational Readiness & Change Management
# **Objective:** To prepare the workforce for AI integration, ensuring employees are capable of using the tools safely and effectively to improve internal workflows.
# *   **Evaluation Criteria:** Employee AI literacy scores (post-training), tool adoption rates across departments, reduction in error rates in AI-assisted tasks, and employee sentiment/engagement surveys.
# *   **Stakeholders:** Chief Human Resources Officer (CHRO), Learning & Development (L&D) Team, Departmental Managers, End-users.
# *   **Dependencies:** Development of tailored training curricula; clearly defined redesigned workflows for impacted job roles.

# %%
#Stage 4
client = genai.Client(api_key=api_key)

PREAMBLE = "You are a synthesizer, turning a problem breakdown over multiple steps into concrete action plans"
problem = "How should an organization decide whether and how to use AI?"

response4 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Using the information given, create a sequential action plan.
                              For each step, include: the action, who is responsible, how we know it is complete,
                              and when to reconsider. Do not make a final decision, just structure the process.""",
                              "Here is the problem:", problem, "Here are the assumptions:", stage2response,"Here are the domains:"
                              ,stage3response]
)

print(response4.text)
stage4response = response4.text
# Out:
# This action plan outlines a structured process for a mid-to-large enterprise to evaluate and implement AI (GenAI and Predictive Analytics) using a "Buy/SaaS" model, focused on ROI and risk mitigation.
#
# ### Phase 1: Strategic Alignment and Financial Feasibility
# **Objective:** Determine if there is a compelling business case for AI adoption.
#
# *   **Step 1: Value Opportunity Mapping**
#     *   **Action:** Identify specific business units (e.g., Customer Support, Marketing) where GenAI or Predictive Analytics can reduce costs or increase revenue. Establish baseline costs for current manual workflows.
#     *   **Who is Responsible:** CEO, CFO, and Business Unit Leaders.
#     *   **How we know it is complete:** A "Business Case Document" exists for each proposed use case, including projected NPV (Net Present Value) and a 12-to-24-month ROI timeline.
#     *   **When to reconsider:** Reconsider if the "Cost of Inaction" is deemed negligible or if the projected ROI is lower than the organization’s standard hurdle rate for capital investments.
#
# ### Phase 2: Risk, Legal, and Compliance Vetting
# **Objective:** Set the safety boundaries for procurement.
#
# *   **Step 2: Vendor Security and Data Privacy Audit**
#     *   **Action:** Evaluate third-party SaaS vendors’ Data Processing Agreements (DPAs) and security certifications (e.g., SOC2, ISO 27001) to ensure proprietary data will not be used to train public models.
#     *   **Who is Responsible:** CISO (Chief Information Security Officer) and General Counsel.
#     *   **How we know it is complete:** A signed "Security Risk Assessment" for the top 3 vendor candidates and a legal sign-off on the privacy framework.
#     *   **When to reconsider:** Reconsider if a vendor cannot provide "Opt-out" clauses for data training or if emerging regional AI regulations (e.g., EU AI Act) create prohibitive compliance costs.
#
# ### Phase 3: Technical Architecture and Data Readiness
# **Objective:** Assess if the organization’s infrastructure can support the chosen tools.
#
# *   **Step 3: Data Integrity and Integration Audit**
#     *   **Action:** Audit internal data quality (cleanliness, bias, and accessibility) and evaluate API compatibility between the SaaS AI tool and existing CRM/ERP systems.
#     *   **Who is Responsible:** CTO (Chief Technology Officer) and Data Engineering Lead.
#     *   **How we know it is complete:** A "Technical Readiness Report" confirming that internal data can feed the AI models without significant cleansing or infrastructure overhaul.
#     *   **When to reconsider:** Reconsider if the "Data Debt" (cost to clean and prep data) exceeds the cost of the AI software itself or if integration requires an unsustainable number of IT man-hours.
#
# ### Phase 4: Governance and Policy Framework
# **Objective:** Establish the "How" for employee usage.
#
# *   **Step 4: Draft and Disseminate "Acceptable Use Policy" (AUP)**
#     *   **Action:** Create a formal policy governing employee interaction with AI, including "Human-in-the-loop" requirements for high-stakes decisions and prohibitions on inputting sensitive customer data.
#     *   **Who is Responsible:** CDO (Chief Data Officer) and HR Leadership.
#     *   **How we know it is complete:** The AUP is finalized, approved by the board, and distributed to all employees with a mandatory acknowledgment.
#     *   **When to reconsider:** Reconsider if the policy is found to be so restrictive that it nullifies the efficiency gains identified in Phase 1.
#
# ### Phase 5: Operational Readiness and Pilot Launch
# **Objective:** Prepare the workforce and test the assumptions in a controlled environment.
#
# *   **Step 5: Targeted Pilot Program and Training**
#     *   **Action:** Launch a 90-day pilot in one department. Provide "AI Literacy" training focused on prompt engineering and identifying AI hallucinations/errors.
#     *   **Who is Responsible:** CHRO (Chief Human Resources Officer) and Departmental Managers.
#     *   **How we know it is complete:** Completion of the 90-day pilot with a "Pilot Performance Report" measuring tool adoption rates and error frequencies.
#     *   **When to reconsider:** Reconsider if employee sentiment shows deep resistance/fear of displacement, or if the pilot reveals unforeseen operational bottlenecks (e.g., employees spending more time "fact-checking" AI than doing the original work).
#
# ### Phase 6: Final Go/No-Go Decision Review
# **Objective:** Synthesis of all data for a final commitment.
#
# *   **Step 6: Executive Synthesis Review**
#     *   **Action:** Compare the Pilot Performance Report (Phase 5) against the initial ROI projections (Phase 1) and Security/Compliance findings (Phase 2).
#     *   **Who is Responsible:** CEO and Executive Steering Committee.
#     *   **How we know it is complete:** A formal meeting where the decision to scale, pivot, or abandon the AI tool is documented.
#     *   **When to reconsider:** This is the final reconsideration point before full-scale organizational rollout.

# %%
#Stage 1 - test case 1
client = genai.Client(api_key=api_key)

PREAMBLE = "Your goal is to identify ambiguity in problem statements."
LAST = "For each ambiguity, quote the unclear term, explain why it matters, and suggest a clarifying question"

response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Identify the ambiguities in the following problem:
    How should a city decide whether to implement congestion pricing?""",LAST]
)

print(response.text)
stage1response = response.text
# Out:
# The problem statement **"How should a city decide whether to implement congestion pricing?"** contains several ambiguities that could lead to very different solutions depending on their interpretation.
#
# Here are the primary ambiguities identified:
#
# ### 1. "How should"
# *   **Why it matters:** This term is unclear because it doesn’t specify the criteria for the decision. "Should" could refer to economic efficiency (cost-benefit analysis), social equity (impact on low-income drivers), environmental goals (emissions reduction), or political feasibility (likelihood of re-election for officials). Without a defined framework, the advice given could be technically sound but practically or ethically irrelevant to the stakeholders.
# *   **Clarifying Question:** What are the primary goals of the city—is the priority revenue generation, traffic reduction, environmental sustainability, or social equity?
#
# ### 2. "a city"
# *   **Why it matters:** Cities vary drastically in terms of population density, existing public transit infrastructure, and legal authority. A decision-making process for New York City (which has high transit density) would look very different from a process for a sprawling city like Houston (where driving is often the only option). The geographical and legal constraints of the specific city change what is "decidable."
# *   **Clarifying Question:** Which specific city are we discussing, and what is the current state of its public transportation infrastructure?
#
# ### 3. "decide"
# *   **Why it matters:** This refers to the governance and procedural mechanism. "Deciding" could mean a top-down executive order by a mayor, a vote by a city council, a public referendum, or a mandate from a state or federal transit authority. The "how" of a public vote is vastly different from the "how" of a technical data analysis.
# *   **Clarifying Question:** Who are the ultimate decision-makers, and what legal or democratic process must be followed to reach a final resolution?
#
# ### 4. "congestion pricing"
# *   **Why it matters:** This is a broad term that covers many different systems. It could mean "cordon pricing" (charging to enter a specific zone), "area pricing" (charging to drive within a zone), "corridor pricing" (tolls on specific high-traffic roads), or "dynamic/variable pricing" (prices that change based on real-time traffic). Each has different costs, technological requirements, and public reception.
# *   **Clarifying Question:** What specific model of congestion pricing is being considered, and what are its intended boundaries?
#
# ### 5. "implement"
# *   **Why it matters:** Implementation can range from a permanent, multi-billion dollar infrastructure overhaul to a small-scale, six-month pilot program using mobile apps. The decision-making process for a permanent law is much more rigorous and high-stakes than the decision to run a temporary trial.
# *   **Clarifying Question:** Is the city considering a permanent rollout or a temporary pilot program to gather data?

# %%
#Stage 2 - test case 1
client = genai.Client(api_key=api_key)

PREAMBLE = """Your goal is to use given identified ambiguity generate assumptions.
              Here is the current problem statement: How should a city decide whether to implement congestion pricing?"""
LAST = """For each assumption, state it clearly, explain why it is reasonable,
          and describe what changes if it is false"""

response2 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , "Identify assumptions given the following ambiguity found: ",stage1response,LAST]
)

print(response2.text)
stage2response = response2.text
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# /tmp/ipython-input-2640641555.py in <cell line: 0>()
#       7           and describe what changes if it is false"""
#       8
# ----> 9 response2 = client.models.generate_content(
#      10     model = "gemini-3-flash-preview",
#      11     contents = [PREAMBLE , "Identify assumptions given the following ambiguity found: ",stage1response,LAST]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5472     while remaining_remote_calls_afc > 0:
#    5473       i += 1
# -> 5474       response = self._generate_content(
#    5475           model=model, contents=contents, config=parsed_config
#    5476       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4212     request_dict = _common.encode_unserializable_types(request_dict)
#    4213
# -> 4214     response = self._api_client.request(
#    4215         'post', path, request_dict, http_options
#    4216     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1384         http_method, path, request_dict, http_options
#    1385     )
# -> 1386     response = self._request(http_request, http_options, stream=False)
#    1387     response_body = (
#    1388         response.response_stream[0] if response.response_stream else ''
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1220         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1221
# -> 1222     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1223
#    1224   async def _async_request_once(
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     469         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     470         while True:
# --> 471             do = self.iter(retry_state=retry_state)
#     472             if isinstance(do, DoAttempt):
#     473                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     370         result = None
#     371         for action in self.iter_state.actions:
# --> 372             result = action(retry_state)
#     373         return result
#     374
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     412                 retry_exc = self.retry_error_cls(fut)
#     413                 if self.reraise:
# --> 414                     raise retry_exc.reraise()
#     415                 raise retry_exc from fut.exception()
#     416
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     183     def reraise(self) -> t.NoReturn:
#     184         if self.last_attempt.failed:
# --> 185             raise self.last_attempt.result()
#     186         raise self
#     187
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     472             if isinstance(do, DoAttempt):
#     473                 try:
# --> 474                     result = fn(*args, **kwargs)
#     475                 except BaseException:  # noqa: B902
#     476                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1197           timeout=http_request.timeout,
#    1198       )
# -> 1199       errors.APIError.raise_for_response(response)
#    1200       return HttpResponse(
#    1201           response.headers, response if stream else [response.text]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     132       response_json = response.body_segments[0].get('error', {})
#     133
# --> 134     cls.raise_error(response.status_code, response_json, response)
#     135
#     136   @classmethod
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     159       raise ClientError(status_code, response_json, response)
#     160     elif 500 <= status_code < 600:
# --> 161       raise ServerError(status_code, response_json, response)
#     162     else:
#     163       raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
#Stage 3 - test case 1
client = genai.Client(api_key=api_key)

PREAMBLE = """You are an expert in problem decomposition. Given the problem and assumptions below,
              produce a decomposition that would apply to THIS problem."""
problem = "How should a city decide whether to implement congestion pricing?"

response3 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """First, provide 5 domains which cover the problem.
                              For each domain, define the objective, identify evaluation criteria,
                              identify stakeholders, and identify dependencies""",problem,stage2response]
)

print(response3.text)
stage3response = response3.text

# %%
#Stage 4 - test case 1
client = genai.Client(api_key=api_key)

PREAMBLE = "You are a synthesizer, turning a problem breakdown over multiple steps into concrete action plans"
problem = "How should a city decide whether to implement congestion pricing?"

response4 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Using the information given, create a sequential action plan.
                              For each step, include: the action, who is responsible, how we know it is complete,
                              and when to reconsider. Do not make a final decision, just structure the process.""",
                              "Here is the problem:", problem, "Here are the assumptions:", stage2response,"Here are the domains:"
                              ,stage3response]
)

print(response4.text)
stage4response = response4.text

# %%
#Stage 1 - test case 2
client = genai.Client(api_key=api_key)

PREAMBLE = "Your goal is to identify ambiguity in problem statements."
LAST = "For each ambiguity, quote the unclear term, explain why it matters, and suggest a clarifying question"

response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Identify the ambiguities in the following problem:
    How should a company decide whether to expand into international markets?""",LAST]
)

print(response.text)
stage1response = response.text

# %%
#Stage 2 - test case 2
client = genai.Client(api_key=api_key)

PREAMBLE = """Your goal is to use given identified ambiguity generate assumptions.
              Here is the current problem statement: How should a company decide whether to expand into international markets?"""
LAST = """For each assumption, state it clearly, explain why it is reasonable,
          and describe what changes if it is false"""

response2 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , "Identify assumptions given the following ambiguity found: ",stage1response,LAST]
)

print(response2.text)
stage2response = response2.text

# %%
#Stage 3 - test case 2
client = genai.Client(api_key=api_key)

PREAMBLE = """You are an expert in problem decomposition. Given the problem and assumptions below,
              produce a decomposition that would apply to THIS problem."""
problem = "How should a company decide whether to expand into international markets?"

response3 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """First, provide 5 domains which cover the problem.
                              For each domain, define the objective, identify evaluation criteria,
                              identify stakeholders, and identify dependencies""",problem,stage2response]
)

print(response3.text)
stage3response = response3.text

# %%
#Stage 4 - test case 2
client = genai.Client(api_key=api_key)

PREAMBLE = "You are a synthesizer, turning a problem breakdown over multiple steps into concrete action plans"
problem = "How should a company decide whether to expand into international markets?"

response4 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Using the information given, create a sequential action plan.
                              For each step, include: the action, who is responsible, how we know it is complete,
                              and when to reconsider. Do not make a final decision, just structure the process.""",
                              "Here is the problem:", problem, "Here are the assumptions:", stage2response,"Here are the domains:"
                              ,stage3response]
)

print(response4.text)
stage4response = response4.text

# %%
#Stage 1 - test case 3
client = genai.Client(api_key=api_key)

PREAMBLE = "Your goal is to identify ambiguity in problem statements."
LAST = "For each ambiguity, quote the unclear term, explain why it matters, and suggest a clarifying question"

response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Identify the ambiguities in the following problem:
    How should a university determine whether to modify its grading system?""",LAST]
)

print(response.text)
stage1response = response.text

# %%
#Stage 2 - test case 3
client = genai.Client(api_key=api_key)

PREAMBLE = """Your goal is to use given identified ambiguity generate assumptions.
              Here is the current problem statement: How should a university determine whether to modify its grading system?"""
LAST = """For each assumption, state it clearly, explain why it is reasonable,
          and describe what changes if it is false"""

response2 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , "Identify assumptions given the following ambiguity found: ",stage1response,LAST]
)

print(response2.text)
stage2response = response2.text

# %%
#Stage 3 - test case 3
client = genai.Client(api_key=api_key)

PREAMBLE = """You are an expert in problem decomposition. Given the problem and assumptions below,
              produce a decomposition that would apply to THIS problem."""
problem = "How should a university determine whether to modify its grading system?"

response3 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """First, provide 5 domains which cover the problem.
                              For each domain, define the objective, identify evaluation criteria,
                              identify stakeholders, and identify dependencies""",problem,stage2response]
)

print(response3.text)
stage3response = response3.text

# %%
#Stage 4 - test case 3
client = genai.Client(api_key=api_key)

PREAMBLE = "You are a synthesizer, turning a problem breakdown over multiple steps into concrete action plans"
problem = "How should a university determine whether to modify its grading system?"

response4 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Using the information given, create a sequential action plan.
                              For each step, include: the action, who is responsible, how we know it is complete,
                              and when to reconsider. Do not make a final decision, just structure the process.""",
                              "Here is the problem:", problem, "Here are the assumptions:", stage2response,"Here are the domains:"
                              ,stage3response]
)

print(response4.text)
stage4response = response4.text
