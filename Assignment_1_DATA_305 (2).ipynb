# %%
api_key = "YOUR_API"

# %%
from google import genai
#Stage 1
client = genai.Client(api_key=api_key)

PREAMBLE = "Your goal is to identify ambiguity in problem statements."
LAST = "For each ambiguity, quote the unclear term, explain why it matters, and suggest a clarifying question"

response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Identify the ambiguities in the following problem:
    How should an organization decide whether and how to use AI?""",LAST]
)

print(response.text)
stage1response = response.text
# Out:
# The problem statement **"How should an organization decide whether and how to use AI?"** contains several layers of ambiguity that would make it difficult to provide a specific, actionable answer.
#
# Here are the key ambiguities identified within the statement:
#
# ### 1. "Organization"
# *   **Why it matters:** The decision-making process for a three-person non-profit is fundamentally different from that of a global financial institution or a government agency. Resources, risk tolerance, regulatory environments, and technical maturity vary wildly across different types of entities.
# *   **Clarifying Question:** What is the size, industry, and regulatory environment of the organization in question?
#
# ### 2. "AI"
# *   **Why it matters:** "AI" is a broad umbrella term. Deciding to use a Generative AI chatbot for internal emails is a low-stakes decision compared to using predictive AI for medical diagnoses or autonomous systems for manufacturing. The "how" and "whether" depend entirely on the specific technology being discussed.
# *   **Clarifying Question:** Are we referring to Generative AI (like LLMs), predictive analytics, computer vision, or automated robotic processes?
#
# ### 3. "Decide"
# *   **Why it matters:** It is unclear who the decision-makers are or what the success criteria are. Does "decide" refer to a financial cost-benefit analysis, a technical feasibility study, or an ethical review board’s approval?
# *   **Clarifying Question:** Who are the stakeholders involved in this decision, and what are the primary KPIs (e.g., ROI, risk mitigation, or speed to market) they are using to measure success?
#
# ### 4. "Use"
# *   **Why it matters:** There is a major distinction between *building* custom AI models, *buying* enterprise software that has AI features, or simply *allowing* employees to use public AI tools. The governance and "how" of each scenario are distinct.
# *   **Clarifying Question:** Does "use" refer to internal operational improvements, external customer-facing products, or the procurement of third-party software?
#
# ### 5. "Should"
# *   **Why it matters:** The word "should" implies a normative standard, but it’s unclear if that standard is based on business profitability, legal compliance, or ethical/social responsibility.
# *   **Clarifying Question:** Is the goal to determine the most *profitable* way to implement AI, the most *ethically responsible* way, or the most *legally compliant* way?
#
# ### 6. "How"
# *   **Why it matters:** "How" could refer to the technical implementation (the architecture), the change management process (training staff), or the procurement strategy (budgeting).
# *   **Clarifying Question:** Does "how" refer to the technical roadmap, the organizational change management, or the governance framework?

# %%
#Stage 2
client = genai.Client(api_key=api_key)

PREAMBLE = """Your goal is to use given identified ambiguity generate assumptions.
              Here is the current problem statement: How should an organization decide
              whether and how to use AI?"""
LAST = """For each assumption, state it clearly, explain why it is reasonable,
          and describe what changes if it is false"""

response2 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , "Identify assumptions given the following ambiguity found: ",stage1response,LAST]
)

print(response2.text)
stage2response = response2.text
# Out:
# To resolve the ambiguities in the problem statement **"How should an organization decide whether and how to use AI?"**, we must establish a set of assumptions. These assumptions provide a consistent context, allowing for a focused and actionable strategy.
#
# Here are the assumptions based on the identified ambiguities:
#
# ---
#
# ### 1. Assumption on "Organization"
# **Assumption:** The organization is a **mid-to-large-scale commercial enterprise** operating in a regulated or semi-regulated industry (e.g., Finance, Healthcare, or Retail).
# *   **Why it is reasonable:** Smaller organizations often lack the resources for formal "decision frameworks," while government agencies have unique mandate-driven requirements. A mid-to-large enterprise represents the "standard" case where there is enough complexity to require a strategy, but enough resource flexibility to act.
# *   **What changes if false:** If the organization is a small non-profit or a startup, the decision process shifts from "governance and risk" to "immediate survival and cost-efficiency." If it is a government body, the priority shifts from "profit/market share" to "public service and equity."
#
# ### 2. Assumption on "AI"
# **Assumption:** "AI" refers primarily to **Generative AI (LLMs)** and **off-the-shelf Predictive Analytics** for business intelligence.
# *   **Why it is reasonable:** These are the most common entry points for organizations today. While "robotics" or "autonomous systems" are also AI, they are niche applications that require highly specialized hardware and safety protocols not applicable to the general business world.
# *   **What changes if false:** If the AI in question is specialized (e.g., autonomous manufacturing robotics), the decision-making process must prioritize physical safety, supply chain logistics, and high-capital expenditure, which are less relevant to software-based AI.
#
# ### 3. Assumption on "Decide"
# **Assumption:** The decision-making process is **centralized and driven by a cross-functional committee** (including IT, Legal, Finance, and Department heads) using a cost-benefit and risk-assessment framework.
# *   **Why it is reasonable:** In a professional setting, a single person rarely decides on technology that affects the entire enterprise. A cross-functional approach is the industry standard for reducing "shadow AI" and ensuring compliance.
# *   **What changes if false:** If the decision is decentralized (allowing individual teams to decide), the framework would focus on "minimum safety standards" rather than a unified corporate strategy.
#
# ### 4. Assumption on "Use"
# **Assumption:** "Use" refers to **integrating third-party AI tools or fine-tuning existing models** for internal productivity and customer-facing enhancements.
# *   **Why it is reasonable:** Most organizations are not "AI creators" (building models from scratch like OpenAI or Google); they are "AI consumers" or "AI tuners." Building from scratch is prohibitively expensive for most entities.
# *   **What changes if false:** If the organization intends to *build* its own foundation models, the decision framework must prioritize massive infrastructure investment, specialized talent acquisition, and vast data harvesting strategies.
#
# ### 5. Assumption on "Should" (Normative Standard)
# **Assumption:** The "Should" is defined by **Commercial Viability and Responsible AI.** This means the decision must lead to a positive Return on Investment (ROI) while adhering to current legal regulations and basic ethical standards (e.g., bias mitigation).
# *   **Why it is reasonable:** For-profit organizations are bound by fiduciary duty to be profitable, but they are also increasingly held accountable by regulators (like the EU AI Act) and public perception.
# *   **What changes if false:** If "should" is defined purely by "profit at any cost," ethical and long-term risk assessments would be discarded. If "should" is purely "altruistic," the organization might reject AI that displaces any labor, regardless of the business benefit.
#
# ### 6. Assumption on "How"
# **Assumption:** "How" refers to the **Strategic Governance Framework**, including the creation of usage policies, the selection of vendors, and the change management process for employees.
# *   **Why it is reasonable:** At an organizational level, "how" is rarely about the specific code; it is about the roadmap, the guardrails, and how the people within the organization will adapt to the new technology.
# *   **What changes if false:** If "how" refers to technical implementation (architecture), the focus would shift to technical debt, API integrations, cloud computing credits, and data engineering pipelines.

# %%
#Stage 3
client = genai.Client(api_key=api_key)

PREAMBLE = """You are an expert in problem decomposition. Given the problem and assumptions below,
              produce a decomposition that would apply to THIS problem."""
problem = "How should an organization decide whether and how to use AI?"

response3 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """First, provide 5 domains which cover the problem.
                              For each domain, define the objective, identify evaluation criteria,
                              identify stakeholders, and identify dependencies""",problem,stage2response]
)

print(response3.text)
stage3response = response3.text
# Out:
# Based on the provided assumptions for a mid-to-large commercial enterprise focusing on software-based AI integration, here is the problem decomposition across five key domains.
#
# ---
#
# ### 1. Strategic & Economic Alignment
# **Objective:** To determine if an AI initiative aligns with the organization’s long-term business goals and provides a justifiable return on investment (ROI).
#
# *   **Evaluation Criteria:**
#     *   **Projected ROI vs. Opportunity Cost:** Comparing the financial gains (or savings) against other non-AI investments.
#     *   **Market Competitiveness:** Assessment of whether the AI tool is necessary to maintain or gain market share.
#     *   **Strategic Fit:** Alignment with the current 3-5 year corporate roadmap.
# *   **Stakeholders:** CEO, Chief Financial Officer (CFO), Board of Directors, Strategy Department.
# *   **Dependencies:** Clear corporate objectives, accurate cost projections from IT, and market trend analysis.
#
# ### 2. Risk, Legal, & Ethical Governance
# **Objective:** To ensure that AI usage complies with industry regulations, protects intellectual property, and adheres to the "Responsible AI" normative standard.
#
# *   **Evaluation Criteria:**
#     *   **Regulatory Compliance:** Alignment with frameworks such as the EU AI Act, GDPR, or HIPAA.
#     *   **Data Privacy & Security:** Evaluation of how third-party vendors handle proprietary enterprise data.
#     *   **Bias & Fairness:** Testing for discriminatory outputs in predictive or generative models.
# *   **Stakeholders:** Chief Legal Officer (CLO), Data Protection Officer (DPO), Ethics Committee, Compliance Officers.
# *   **Dependencies:** Current legal landscape/jurisdiction, vendor transparency, and finalized internal "Usage Policies."
#
# ### 3. Technical Feasibility & Data Infrastructure
# **Objective:** To assess whether the organization possesses the data quality, technical architecture, and vendor partnerships necessary to implement the AI solution.
#
# *   **Evaluation Criteria:**
#     *   **Data Hygiene:** Accuracy, completeness, and accessibility of the data required to fine-tune or prompt the AI.
#     *   **Scalability:** Ability of the current IT infrastructure (cloud or on-prem) to handle AI workloads.
#     *   **Vendor Viability:** Reliability and API uptime of third-party AI providers (e.g., OpenAI, Microsoft, Google).
# *   **Stakeholders:** Chief Technology Officer (CTO), Chief Information Officer (CIO), Data Engineers, Enterprise Architects.
# *   **Dependencies:** Data availability, cloud service provider agreements, and existing software stack compatibility.
#
# ### 4. Human Capital & Change Management
# **Objective:** To manage the workforce transition, identify skill gaps, and ensure that AI tools are actually adopted by employees.
#
# *   **Evaluation Criteria:**
#     *   **Skill Gap Analysis:** Identifying the delta between current employee capabilities and those needed to use/manage AI.
#     *   **Adoption Sentiment:** Measuring employee willingness and cultural readiness to integrate AI into their workflows.
#     *   **Productivity Impact:** Measuring changes in employee output and job satisfaction post-implementation.
# *   **Stakeholders:** Chief Human Resources Officer (CHRO), Department Heads, Internal Communications, Front-line Employees.
# *   **Dependencies:** Quality of upskilling/training programs, leadership "buy-in," and clear communication regarding job security.
#
# ### 5. Operational Integration & Lifecycle Management
# **Objective:** To define the roadmap for deploying, monitoring, and maintaining AI systems over time to prevent "model drift" or technical debt.
#
# *   **Evaluation Criteria:**
#     *   **Implementation Speed:** Time-to-market for the initial Pilot/MVP (Minimum Viable Product).
#     *   **Operational Reliability:** Success rate of AI integration into existing business processes without disruption.
#     *   **Maintenance Sustainability:** The long-term cost and labor required to keep the AI system updated and accurate.
# *   **Stakeholders:** Chief Operating Officer (COO), Product Managers, MLOps (Machine Learning Operations) Team, Customer Success.
# *   **Dependencies:** Success of the Technical Feasibility phase, availability of a cross-functional oversight committee, and feedback loops from end-users.

# %%
#Stage 4
client = genai.Client(api_key=api_key)

PREAMBLE = "You are a synthesizer, turning a problem breakdown over multiple steps into concrete action plans"
problem = "How should an organization decide whether and how to use AI?"

response4 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Using the information given, create a sequential action plan.
                              For each step, include: the action, who is responsible, how we know it is complete,
                              and when to reconsider. Do not make a final decision, just structure the process.""",
                              "Here is the problem:", problem, "Here are the assumptions:", stage2response,"Here are the domains:"
                              ,stage3response]
)

print(response4.text)
stage4response = response4.text
# Out:
# This sequential action plan outlines the process for a mid-to-large enterprise to evaluate and implement AI, moving from high-level strategy to operational readiness.
#
# ### Phase 1: Foundation and Governance
# **Step 1: Establish the AI Decision Committee (AIDC)**
# *   **Action:** Form a cross-functional committee to oversee AI strategy, ensuring representation from all critical domains.
# *   **Responsibility:** CEO and Board of Directors.
# *   **How we know it is complete:** A formal charter is signed, and representatives from IT, Legal, Finance, HR, and Operations are officially appointed.
# *   **When to reconsider:** If department-level "shadow AI" (unauthorized tool use) increases, suggesting the committee is too slow or disconnected from local needs.
#
# ### Phase 2: Strategic Discovery and Economic Filtering
# **Step 2: Use-Case Identification and ROI Modeling**
# *   **Action:** Conduct a discovery phase to identify potential GenAI and Predictive Analytics use cases, followed by a formal Cost-Benefit Analysis (CBA) for each.
# *   **Responsibility:** CFO and Strategy Department.
# *   **How we know it is complete:** A prioritized "Shortlist" of 3–5 high-value use cases is produced, each with a projected ROI and 3-year cost estimate.
# *   **When to reconsider:** If the opportunity cost of these projects exceeds the projected gains from non-AI digital transformation initiatives.
#
# ### Phase 3: Risk and Regulatory Scrub
# **Step 3: Responsible AI and Compliance Audit**
# *   **Action:** Evaluate the shortlisted use cases against the "Responsible AI" standard, focusing on data privacy, bias mitigation, and regulatory alignment (e.g., EU AI Act, GDPR).
# *   **Responsibility:** Chief Legal Officer (CLO) and Data Protection Officer (DPO).
# *   **How we know it is complete:** A Risk Assessment Report is issued for each use case, classifying them as Green (Low Risk), Yellow (Mitigation Required), or Red (High Risk/Halt).
# *   **When to reconsider:** If new regulations are passed or if a primary AI vendor changes their data privacy terms significantly.
#
# ### Phase 4: Technical and Data Infrastructure Audit
# **Step 4: Data Hygiene and Vendor Capability Assessment**
# *   **Action:** Assess the quality and accessibility of internal data required for the shortlisted use cases and evaluate the reliability of third-party API providers.
# *   **Responsibility:** CTO and CIO.
# *   **How we know it is complete:** A "Technical Readiness Scorecard" is finalized, confirming that the data is "clean" enough and the cloud infrastructure can support the workload.
# *   **When to reconsider:** If internal data silos prove too difficult to break down or if vendor API costs escalate beyond the initial CBA.
#
# ### Phase 5: Workforce and Cultural Readiness
# **Step 5: Skill Gap Analysis and Change Management Strategy**
# *   **Action:** Identify the skills needed to use the new AI tools and measure the cultural readiness/sentiment of the employees who will use them.
# *   **Responsibility:** CHRO and Department Heads.
# *   **How we know it is complete:** An "AI Training and Adoption Plan" is drafted, including a timeline for upskilling and a transparent internal communication schedule regarding job impact.
# *   **When to reconsider:** If initial employee surveys indicate high levels of fear or resistance that could lead to low adoption or attrition of key talent.
#
# ### Phase 6: Operational Synthesis and Pilot Design
# **Step 6: Development of the Strategic AI Playbook (Final Recommendation)**
# *   **Action:** Synthesize the findings from the previous five steps into a single implementation roadmap (Pilot/MVP design).
# *   **Responsibility:** AI Decision Committee (AIDC).
# *   **How we know it is complete:** A "Go/No-Go" presentation is delivered to the Board, detailing which specific AI tools will be used, how they will be governed, and the metrics for pilot success.
# *   **When to reconsider:** If the competitive landscape shifts (e.g., a competitor releases a disruptive AI feature) or if the pilot's technical requirements change during the design phase.

# %%
#Stage 1 - test case 1
client = genai.Client(api_key=api_key)

PREAMBLE = "Your goal is to identify ambiguity in problem statements."
LAST = "For each ambiguity, quote the unclear term, explain why it matters, and suggest a clarifying question"

response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Identify the ambiguities in the following problem:
    How should a city decide whether to implement congestion pricing?""",LAST]
)

print(response.text)
stage1response = response.text
# Out:
# To provide a rigorous answer to the problem of whether to implement congestion pricing, several ambiguities must first be resolved. Here are the primary unclear terms:
#
# ### 1. “Congestion pricing”
# *   **Why it matters:** Congestion pricing is not a single strategy; it encompasses various models such as **cordon pricing** (charging to enter a zone), **corridor pricing** (tolling specific roads), or **dynamic/variable pricing** (costs change based on real-time traffic). The criteria for deciding to use a toll lane on one highway are very different from the criteria for charging every car that enters a downtown core.
# *   **Clarifying Question:** What specific model of congestion pricing is being proposed, and what are the geographic boundaries of the pricing zone?
#
# ### 2. “City”
# *   **Why it matters:** The term "city" can refer to the municipal government, the geographic urban area, or the entire metropolitan region including suburbs. A decision that benefits the "city" (the urban core) might negatively impact the "region" (commuters). Furthermore, the legal authority to implement such a plan varies depending on whether the city has "home rule" or is dependent on state/provincial approval.
# *   **Clarifying Question:** Does "city" refer to the municipal administration, and does that body have the legal jurisdiction to implement pricing without state or federal intervention?
#
# ### 3. “How should… decide”
# *   **Why it matters:** This phrase is ambiguous regarding the **process** versus the **metrics**. It could be asking for a political process (e.g., a public referendum, a city council vote, or an executive order) or a technical framework (e.g., a cost-benefit analysis, environmental impact study, or equity audit).
# *   **Clarifying Question:** Are you seeking a political framework for stakeholder engagement and approval, or a technical framework based on data-driven KPIs?
#
# ### 4. The implicit goal of the decision (The "Why")
# *   **Why it matters:** The word "decide" implies a choice based on a goal, but the goal is unstated. If the goal is **revenue generation**, the decision hinges on fiscal projections. If the goal is **emissions reduction**, it hinges on environmental data. If the goal is **traffic speed**, it hinges on throughput metrics. Without a defined goal, "deciding" has no benchmark for success.
# *   **Clarifying Question:** What is the primary objective of the policy—reducing traffic volume, improving air quality, or generating revenue for public transit?
#
# ### 5. “Implement”
# *   **Why it matters:** Implementation can be permanent, or it can be a "pilot program." A city might decide to implement a 6-month trial to gather data before making a final decision. The risks and decision-making criteria for a temporary trial are significantly lower than for a permanent infrastructure overhaul.
# *   **Clarifying Question:** Is the decision regarding a permanent policy rollout or a time-bound pilot program to test feasibility?

# %%
#Stage 2 - test case 1
client = genai.Client(api_key=api_key)

PREAMBLE = """Your goal is to use given identified ambiguity generate assumptions.
              Here is the current problem statement: How should a city decide whether to implement congestion pricing?"""
LAST = """For each assumption, state it clearly, explain why it is reasonable,
          and describe what changes if it is false"""

response2 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , "Identify assumptions given the following ambiguity found: ",stage1response,LAST]
)

print(response2.text)
stage2response = response2.text
# Out:
# Based on the ambiguities identified in the problem statement, "How should a city decide whether to implement congestion pricing?", the following assumptions have been made to provide a structured framework for an answer.
#
# ---
#
# ### 1. Assumption: The model is "Cordon Pricing" focused on the urban core.
# *   **The Assumption:** We assume "congestion pricing" refers to a **cordon model**, where drivers are charged a fee to enter a clearly defined central business district or high-traffic downtown area.
# *   **Why it is reasonable:** This is the most common and comprehensive model used by major global cities (e.g., London, Stockholm, Singapore) when discussing city-wide policy. It generates the most significant debate regarding equity, commerce, and transit.
# *   **What changes if false:** If the model is **corridor pricing** (tolling a single bridge or highway), the decision-making process shifts from urban planning and social equity to traffic engineering and "leakage" (drivers taking side streets to avoid the toll).
#
# ### 2. Assumption: The "City" refers to a municipal government with legal jurisdiction.
# *   **The Assumption:** We assume the "city" is the municipal governing body (e.g., City Council or Mayor’s Office) and that it possesses, or can reasonably obtain, the legal authority to set tolls without being blocked by state, provincial, or federal entities.
# *   **Why it is reasonable:** To answer "how a city should decide," we must assume the city has the agency to act. If the city has no power to implement the change, the question of "how to decide" is moot.
# *   **What changes if false:** If the city lacks legal jurisdiction (e.g., the state owns the roads), the decision-making process is no longer about policy implementation; it becomes a political lobbying strategy to convince a higher level of government to act.
#
# ### 3. Assumption: The "Decision" is based on a Technical-Analytical Framework.
# *   **The Assumption:** We assume the word "decide" refers to a **data-driven evaluation process** (utilizing KPIs and cost-benefit analyses) rather than a purely political process (like a public referendum).
# *   **Why it is reasonable:** Professional urban planning typically requires a rigorous evidence-based approach to justify significant infrastructure and economic shifts to the public and stakeholders.
# *   **What changes if false:** If the decision is to be made via **public referendum**, the "how" changes from analyzing traffic data and economic impact to analyzing public sentiment, communication strategies, and political coalition-building.
#
# ### 4. Assumption: The primary goal is a "Triple Bottom Line" (Traffic, Revenue, Environment).
# *   **The Assumption:** We assume the objective is to simultaneously reduce traffic congestion, generate revenue for public transit, and lower carbon emissions.
# *   **Why it is reasonable:** Most modern congestion pricing proposals are marketed as multi-purpose solutions. Focusing on just one (e.g., only revenue) is rare in modern urban policy due to political optics.
# *   **What changes if false:** If the goal is **purely revenue generation**, the city would set prices to maximize profit regardless of traffic flow. If the goal is **purely environmental**, the city might ignore revenue and focus on banning certain vehicle types altogether.
#
# ### 5. Assumption: "Implementation" refers to a permanent policy following a pilot phase.
# *   **The Assumption:** We assume the city is deciding on a long-term, permanent infrastructure rollout, but that the decision includes a "trial period" to gather local data before finalization.
# *   **Why it is reasonable:** High capital costs for enforcement technology (cameras, sensors) usually imply a permanent move, but successful precedents (like Stockholm) used a pilot to win public approval.
# *   **What changes if false:** If the implementation is a **temporary pilot only**, the barrier for "deciding" is much lower, as the risks are reversible and the focus is on experimentation rather than long-term economic restructuring.

# %%
#Stage 3 - test case 1
client = genai.Client(api_key=api_key)

PREAMBLE = """You are an expert in problem decomposition. Given the problem and assumptions below,
              produce a decomposition that would apply to THIS problem."""
problem = "How should a city decide whether to implement congestion pricing?"

response3 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """First, provide 5 domains which cover the problem.
                              For each domain, define the objective, identify evaluation criteria,
                              identify stakeholders, and identify dependencies""",problem,stage2response]
)

print(response3.text)
stage3response = response3.text
# Out:
# Based on the assumptions that this decision is a data-driven, municipal-led evaluation of a permanent cordon pricing model focused on a "Triple Bottom Line" (Traffic, Revenue, Environment), the problem can be decomposed into the following five domains:
#
# ---
#
# ### 1. Transportation & Mobility Engineering
# **Objective:** To optimize urban flow by reducing private vehicle congestion and increasing the efficiency and reliability of public transit and alternative modes of transport.
#
# *   **Evaluation Criteria:**
#     *   Reduction in Vehicle Miles Traveled (VMT) within the cordon.
#     *   Average travel speed/time savings for transit and remaining vehicles.
#     *   "Leakage" rates (increase in traffic on peripheral streets outside the cordon).
#     *   Reliability of transit schedules (on-time performance).
# *   **Stakeholders:** Transit agencies (bus/rail), taxi and rideshare drivers, logistics/delivery companies, and daily commuters.
# *   **Dependencies:** Pre-existing capacity of public transit (can the system absorb new riders shifted out of cars?) and the quality of data from traffic sensors/modeling software.
#
# ### 2. Economic Vitality & Fiscal Management
# **Objective:** To ensure the program generates sufficient net revenue for transit reinvestment while maintaining the economic competitiveness of the Central Business District (CBD).
#
# *   **Evaluation Criteria:**
#     *   Net revenue (Gross toll revenue minus high operating/enforcement costs).
#     *   Impact on CBD retail sales and foot traffic.
#     *   Changes in business operating costs for service and delivery providers.
#     *   Benefit-Cost Ratio (BCR) based on time-savings vs. toll costs.
# *   **Stakeholders:** Municipal Finance Department, Chambers of Commerce, local business owners, and taxpayers.
# *   **Dependencies:** Price elasticity of drivers (how sensitive drivers are to the fee) and the administrative costs of the tolling technology.
#
# ### 3. Social Equity & Public Policy
# **Objective:** To ensure the pricing structure does not disproportionately burden low-income individuals or "transit-desert" residents, maintaining equitable access to the city core.
#
# *   **Evaluation Criteria:**
#     *   Percentage of household income spent on transportation for the bottom quintile.
#     *   Accessibility metrics for "essential workers" who cannot work remotely.
#     *   Availability and uptake of "equity discounts" or exemptions for low-income drivers.
#     *   Geographic equity (impact on residents living just outside the cordon boundary).
# *   **Stakeholders:** Social justice advocacy groups, disability rights organizations, low-income residents, and labor unions.
# *   **Dependencies:** Geographic distribution of existing transit infrastructure and the legal ability to offer tiered pricing based on income.
#
# ### 4. Environmental Sustainability & Public Health
# **Objective:** To reduce the negative externalities of driving, specifically focusing on decarbonization, local air quality improvement, and urban livability.
#
# *   **Evaluation Criteria:**
#     *   Reduction in Particulate Matter (PM2.5) and Nitrogen Oxides (NOx) within the cordon.
#     *   Total reduction in CO2 emissions attributable to the policy.
#     *   Reduction in noise pollution levels (decibels) in the urban core.
#     *   Changes in rates of pedestrian/cyclist accidents and respiratory-related hospital visits.
# *   **Stakeholders:** Public health officials, environmental NGOs, urban residents, and non-motorized commuters (cyclists/pedestrians).
# *   **Dependencies:** The current vehicle fleet composition (percentage of EVs vs. ICE) and local meteorological patterns that affect smog.
#
# ### 5. Operational Infrastructure & Data Privacy
# **Objective:** To design and maintain a reliable, secure, and legally compliant technological system for toll collection and enforcement.
#
# *   **Evaluation Criteria:**
#     *   Accuracy rates of License Plate Recognition (LPR) or transponder systems.
#     *   System uptime and cybersecurity resilience.
#     *   Data privacy compliance (how long is movement data stored and who sees it?).
#     *   Administrative efficiency (ease of payment for users; rate of successful fine collection).
# *   **Stakeholders:** IT and systems vendors, law enforcement agencies, data privacy advocates, and municipal IT departments.
# *   **Dependencies:** Legal frameworks for automated enforcement (red-light/speed camera laws) and the availability of high-speed connectivity (5G/Fiber) across the cordon boundary.

# %%
#Stage 4 - test case 1
client = genai.Client(api_key=api_key)

PREAMBLE = "You are a synthesizer, turning a problem breakdown over multiple steps into concrete action plans"
problem = "How should a city decide whether to implement congestion pricing?"

response4 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Using the information given, create a sequential action plan.
                              For each step, include: the action, who is responsible, how we know it is complete,
                              and when to reconsider. Do not make a final decision, just structure the process.""",
                              "Here is the problem:", problem, "Here are the assumptions:", stage2response,"Here are the domains:"
                              ,stage3response]
)

print(response4.text)
stage4response = response4.text
# Out:
# This action plan outlines a sequential, data-driven process for a municipal government to determine the feasibility and implementation of a permanent cordon-based congestion pricing model.
#
# ### Phase 1: Baseline Assessment & Objective Setting
# **Step 1: Establish "Triple Bottom Line" Baseline Data**
# *   **Action:** Collect 12 months of high-resolution data on traffic volume (VMT), transit load factors, air quality (PM2.5/NOx), and CBD retail sales to establish a pre-policy benchmark.
# *   **Responsibility:** Municipal Department of Transportation (DOT) in coordination with the Environmental Protection Agency and Finance Department.
# *   **How we know it is complete:** A "State of the City Core" report is published, providing the statistical foundation for all future modeling.
# *   **When to reconsider:** Reconsider if baseline data reveals that traffic or emissions are already trending downward significantly due to external factors (e.g., permanent shifts in remote work).
#
# ### Phase 2: Predictive Modeling & Scenario Planning
# **Step 2: Conduct Multi-Scenario Mobility and Fiscal Modeling**
# *   **Action:** Utilize traffic simulation software to test various price points (e.g., peak vs. off-peak) and their impact on "leakage" (traffic diverting to side streets) and price elasticity.
# *   **Responsibility:** Lead Urban Planning Consultant and Municipal Finance Department.
# *   **How we know it is complete:** A Benefit-Cost Analysis (BCA) is produced for three distinct pricing tiers, including projected net revenue after operational costs.
# *   **When to reconsider:** Reconsider if modeling shows that the "leakage" into residential neighborhoods outside the cordon creates a net-negative safety or congestion outcome.
#
# ### Phase 3: Equity and Stakeholder Integration
# **Step 3: Design Equity Framework and Mitigation Strategy**
# *   **Action:** Identify "transit deserts" and low-income demographics to design targeted exemptions, income-based discounts, and essential worker credits.
# *   **Responsibility:** Office of Social Equity and Public Policy Committee.
# *   **How we know it is complete:** A formalized "Equity & Access Plan" is integrated into the pricing proposal, including a legal review of tiered pricing.
# *   **When to reconsider:** Reconsider if the cost of administering discounts and exemptions exceeds 30% of projected gross revenue, threatening the program's fiscal viability.
#
# ### Phase 4: Operational Design & Infrastructure Procurement
# **Step 4: Execute RFP for Cordon Technology and Data Privacy Systems**
# *   **Action:** Issue a Request for Proposals (RFP) for License Plate Recognition (LPR) hardware and a secure, privacy-compliant payment backend.
# *   **Responsibility:** Chief Information Officer (CIO) and Procurement Office.
# *   **How we know it is complete:** A vendor is selected who meets 99% accuracy requirements for tolling and adheres to municipal data retention/privacy laws.
# *   **When to reconsider:** Reconsider if no vendor can guarantee data privacy standards or if the capital expenditure for infrastructure exceeds the three-year revenue forecast.
#
# ### Phase 5: The Pilot Program (The Trial Phase)
# **Step 5: Launch and Monitor a 6-Month Pilot Implementation**
# *   **Action:** Activate the cordon pricing technology for a limited trial period with "soft enforcement" (initial warnings or reduced fines) to gather real-world behavioral data.
# *   **Responsibility:** Project Management Office (PMO) and Municipal DOT.
# *   **How we know it is complete:** The 6-month period concludes with a comprehensive data set comparing pilot performance against the Phase 1 baseline.
# *   **When to reconsider:** Reconsider immediately if transit systems experience "crush loads" that exceed safety capacities, or if CBD retail foot traffic drops beyond a pre-defined "critical loss" threshold (e.g., >15%).
#
# ### Phase 6: Final Synthesis and Decision Logic
# **Step 6: Final "Go/No-Go" Evaluation Synthesis**
# *   **Action:** Synthesize pilot data across the five domains (Transportation, Economics, Equity, Environment, Operations) into a final recommendation report for the City Council.
# *   **Responsibility:** City Manager or Mayor’s Chief of Staff.
# *   **How we know it is complete:** The delivery of a formal recommendation report that compares pilot outcomes against the original "Triple Bottom Line" KPIs.
# *   **When to reconsider:** Reconsider the move to a permanent policy if the pilot data reveals that the net environmental and traffic gains are statistically insignificant compared to the economic burden on residents.

# %%
#Stage 1 - test case 2
client = genai.Client(api_key=api_key)

PREAMBLE = "Your goal is to identify ambiguity in problem statements."
LAST = "For each ambiguity, quote the unclear term, explain why it matters, and suggest a clarifying question"

response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Identify the ambiguities in the following problem:
    How should a company decide whether to expand into international markets?""",LAST]
)

print(response.text)
stage1response = response.text
# Out:
# To provide a rigorous answer to the question "How should a company decide whether to expand into international markets?", several key ambiguities must be resolved. Here are the primary points of uncertainty:
#
# ### 1. "A company"
# *   **Why it matters:** The decision-making criteria for a multinational conglomerate (e.g., Apple or Toyota) are vastly different from those of a small family-owned business or a digital-first startup. Resources, risk tolerance, and existing infrastructure vary significantly by company size, industry, and maturity.
# *   **Clarifying Question:** What is the size, industry, and current financial standing of the company in question?
#
# ### 2. "Expand"
# *   **Why it matters:** "Expansion" is a broad term that can refer to many different entry strategies. A company might "expand" via low-risk exporting, medium-risk licensing or franchising, or high-risk Foreign Direct Investment (FDI) like building a factory abroad. Each requires a different level of capital and a different decision-making framework.
# *   **Clarifying Question:** What specific mode of entry (e.g., exporting, joint venture, or physical relocation) is being considered?
#
# ### 3. "International markets"
# *   **Why it matters:** Not all foreign markets are equal. Deciding to enter a "near-market" (culturally or geographically similar, like a U.S. company moving into Canada) involves different hurdles than entering an "emerging market" (with high volatility and different regulatory standards). The level of institutional distance dictates the complexity of the decision.
# *   **Clarifying Question:** Is the company looking at a specific geographic region or a specific type of market (e.g., developed vs. emerging)?
#
# ### 4. "Should"
# *   **Why it matters:** The word "should" implies a set of values or a specific goal. One company "should" expand if their goal is immediate revenue growth, while another "should" stay local if their goal is risk mitigation or maintaining a domestic supply chain. Without a defined objective, the "should" is subjective.
# *   **Clarifying Question:** What is the primary strategic objective for this expansion (e.g., profit maximization, market share growth, or risk diversification)?
#
# ### 5. "Decide"
# *   **Why it matters:** This term refers to the decision-making process. It is unclear if the user is looking for a **quantitative** framework (like Net Present Value or ROI calculations) or a **qualitative** framework (like PESTEL analysis or a SWOT assessment of the new region).
# *   **Clarifying Question:** Are you looking for a financial model to calculate profitability, or a strategic framework to assess market environment and cultural fit?

# %%
#Stage 2 - test case 2
client = genai.Client(api_key=api_key)

PREAMBLE = """Your goal is to use given identified ambiguity generate assumptions.
              Here is the current problem statement: How should a company decide whether to expand into international markets?"""
LAST = """For each assumption, state it clearly, explain why it is reasonable,
          and describe what changes if it is false"""

response2 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , "Identify assumptions given the following ambiguity found: ",stage1response,LAST]
)

print(response2.text)
stage2response = response2.text
# Out:
# Based on the ambiguities identified, here are five assumptions that allow for a structured and rigorous answer to the question: **"How should a company decide whether to expand into international markets?"**
#
# ---
#
# ### Assumption 1: The Company is an Established Mid-to-Large Enterprise
# *   **The Assumption:** We assume "a company" refers to a mature organization with a proven domestic product/service, stable cash flow, and the organizational capacity to support a new division or region.
# *   **Why it is reasonable:** Small startups often lack the capital for formal international expansion, while massive multinational conglomerates already have established global frameworks. Mid-to-large enterprises face the most critical "crossroads" decisions regarding whether to step onto the global stage.
# *   **What changes if false:** If the company is a "born-global" digital startup, the decision process shifts from physical infrastructure and capital investment to digital localization, server scalability, and global user acquisition costs.
#
# ### Assumption 2: Expansion involves a Moderate-to-High Commitment Entry Mode
# *   **The Assumption:** We assume "expand" refers to a strategy involving significant resource commitment, such as a Joint Venture (JV), licensing, or establishing a physical subsidiary (Foreign Direct Investment), rather than simple passive exporting.
# *   **Why it is reasonable:** Passive exporting (e.g., fulfilling international orders via a website) requires very little strategic "decision-making." A formal framework is most necessary when the company must commit significant personnel, capital, and brand reputation to a foreign market.
# *   **What changes if false:** If the expansion is low-risk (e.g., selling through a third-party global distributor), the decision-making process becomes almost entirely focused on logistics, shipping costs, and legal compliance rather than strategic market fit.
#
# ### Assumption 3: The Target Market is an "Emerging Market" or "Distal Market"
# *   **The Assumption:** We assume the company is looking at a market with significant "institutional distance"—meaning different regulatory, cultural, and economic environments than their home country.
# *   **Why it is reasonable:** Expanding from the U.S. to Canada or from Germany to Austria involves minimal friction. The "should" of the decision is only truly tested when the company must navigate complex barriers, such as entering a market like India, Brazil, or Vietnam.
# *   **What changes if false:** If the target is a "near-market" (culturally and geographically similar), the decision-making process simplifies into a basic cost-benefit analysis, as cultural adaptation and regulatory hurdles are negligible.
#
# ### Assumption 4: The Primary Goal is Long-Term Revenue Growth and Diversification
# *   **The Assumption:** We assume the "should" is driven by a desire for sustainable top-line growth and the mitigation of domestic market saturation.
# *   **Why it is reasonable:** While companies expansion for many reasons, the most common strategic driver is the need to find new customer bases to ensure long-term survival and satisfy shareholders.
# *   **What changes if false:** If the goal is purely "asset-seeking" (e.g., expanding to secure cheaper raw materials or specialized talent), the decision-making criteria shift from "market demand and competition" to "supply chain efficiency and labor laws."
#
# ### Assumption 5: The Decision Process requires a "Hybrid" Framework
# *   **The Assumption:** We assume the "decide" process must include both quantitative financial modeling (e.g., NPV, ROI) and qualitative strategic analysis (e.g., PESTEL, CAGE Distance Framework).
# *   **Why it is reasonable:** Financials alone cannot account for political instability or cultural rejection of a brand, and qualitative analysis alone cannot justify the capital expenditure to a Board of Directors. A rigorous answer requires balancing both.
# *   **What changes if false:** If only a quantitative framework is used, the company risks a "numbers-only" failure where the math looks good but the local culture rejects the product. If only qualitative, the company risks "strategic vanity" projects that lose money despite being a "good fit."

# %%
#Stage 3 - test case 2
client = genai.Client(api_key=api_key)

PREAMBLE = """You are an expert in problem decomposition. Given the problem and assumptions below,
              produce a decomposition that would apply to THIS problem."""
problem = "How should a company decide whether to expand into international markets?"

response3 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """First, provide 5 domains which cover the problem.
                              For each domain, define the objective, identify evaluation criteria,
                              identify stakeholders, and identify dependencies""",problem,stage2response]
)

print(response3.text)
stage3response = response3.text
# Out:
# To decide whether to expand into a distal international market with a high-commitment entry mode, the problem is decomposed into the following five domains. This decomposition integrates the hybrid framework (qualitative and quantitative) required for a mid-to-large enterprise.
#
# ---
#
# ### 1. Strategic Market Attractiveness & Alignment
# **Objective:** To determine if the target "distal" market offers sufficient long-term growth potential to justify the strategic pivot and align with the company’s diversification goals.
#
# *   **Evaluation Criteria:**
#     *   **CAGE Distance Analysis:** Scoring the Cultural, Administrative, Geographic, and Economic distance between the home and target markets.
#     *   **Market Concentration:** Assessment of local competitor dominance vs. the company’s unique value proposition.
#     *   **Total Addressable Market (TAM):** Quantifying the long-term revenue ceiling in the emerging economy.
# *   **Stakeholders:** Chief Strategy Officer (CSO), Board of Directors, Market Research Agencies, Head of Business Development.
# *   **Dependencies:** Accurate macroeconomic data on the emerging market; internal consensus on what constitutes "saturation" in the domestic market.
#
# ### 2. Financial Modeling & Risk-Adjusted Valuation
# **Objective:** To apply a rigorous quantitative lens to the expansion, ensuring the high-commitment investment (FDI or JV) meets internal hurdles for ROI and NPV.
#
# *   **Evaluation Criteria:**
#     *   **Net Present Value (NPV) & IRR:** Calculating projected cash flows adjusted for the high cost of capital in emerging markets.
#     *   **Currency & Inflation Risk:** Modeling the impact of exchange rate volatility on profit repatriation.
#     *   **Breakeven Timeline:** Determining the duration the enterprise must sustain "burn" before the international division becomes self-funding.
# *   **Stakeholders:** CFO, Investment Bankers, Tax Advisory Firms, Shareholders/Investors.
# *   **Dependencies:** Revenue projections from the Strategic Assessment domain; local tax law data; capital expenditure (CapEx) availability.
#
# ### 3. Institutional & Regulatory Compliance
# **Objective:** To navigate the "institutional distance" by identifying legal barriers, protecting intellectual property, and ensuring political viability.
#
# *   **Evaluation Criteria:**
#     *   **IP Protection Strength:** Assessing the local legal system’s ability to defend the company’s proprietary technology or brand.
#     *   **Regulatory Friction:** Evaluating the ease of obtaining permits, licenses, and the complexity of local labor laws.
#     *   **Political Stability Index:** Measuring the risk of sudden policy shifts, expropriation, or civil unrest.
# *   **Stakeholders:** General Counsel (Legal), Compliance Officers, Local Government Liaisons, Geopolitical Risk Consultants.
# *   **Dependencies:** Trade treaties between the home country and the target market; status of local entity registration requirements.
#
# ### 4. Operational Infrastructure & Entry Mode Execution
# **Objective:** To design the physical and organizational "pipes" required for high-commitment expansion, such as supply chains and local subsidiaries.
#
# *   **Evaluation Criteria:**
#     *   **Supply Chain Resilience:** Availability of local tier-1 suppliers vs. the cost of importing raw materials.
#     *   **Partner Compatibility (for JVs):** Due diligence on the financial health and reputation of potential local partners.
#     *   **Logistics Performance Index (LPI):** Evaluating the target market’s ports, roads, and digital infrastructure.
# *   **Stakeholders:** COO, Supply Chain Director, Local JV Partners, Logistics Providers.
# *   **Dependencies:** Decision on the specific entry mode (e.g., Green-field investment vs. Acquisition); local site selection.
#
# ### 5. Organizational Readiness & Cultural Localization
# **Objective:** To ensure the company’s "DNA" and product offerings can be successfully adapted to a culturally distal environment without losing brand equity.
#
# *   **Evaluation Criteria:**
#     *   **Product-Market Fit (Localization):** The degree of modification required for the product to meet local tastes, standards, or religious requirements.
#     *   **Human Capital Pipeline:** Availability of local management talent vs. the cost of relocating expatriate leaders.
#     *   **Global Mindset Score:** Assessment of the domestic leadership’s ability to manage a culturally diverse and geographically dispersed workforce.
# *   **Stakeholders:** CHRO (Human Resources), Chief Marketing Officer (CMO), Local Brand Managers, Training & Development Teams.
# *   **Dependencies:** Insights from the Strategic Market domain; internal HR budget for international relocation and local hiring.

# %%
#Stage 4 - test case 2
client = genai.Client(api_key=api_key)

PREAMBLE = "You are a synthesizer, turning a problem breakdown over multiple steps into concrete action plans"
problem = "How should a company decide whether to expand into international markets?"

response4 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Using the information given, create a sequential action plan.
                              For each step, include: the action, who is responsible, how we know it is complete,
                              and when to reconsider. Do not make a final decision, just structure the process.""",
                              "Here is the problem:", problem, "Here are the assumptions:", stage2response,"Here are the domains:"
                              ,stage3response]
)

print(response4.text)
stage4response = response4.text
# Out:
# This action plan provides a sequential structure for an established mid-to-large enterprise to evaluate expansion into a distal emerging market using a high-commitment entry mode.
#
# ### Phase 1: Strategic Alignment & Market Opportunity
#
# **Step 1: Strategic Market Attractiveness & CAGE Analysis**
# *   **Action:** Conduct a CAGE (Cultural, Administrative, Geographic, Economic) Distance Analysis and quantify the Total Addressable Market (TAM) to ensure the target market aligns with the company’s long-term diversification goals.
# *   **Who is Responsible:** Chief Strategy Officer (CSO) and external Market Research Agencies.
# *   **How we know it is complete:** A "Market Potential Report" is delivered, ranking the market's attractiveness relative to other global opportunities and confirming the TAM exceeds the company's minimum threshold for expansion.
# *   **When to reconsider:** If the "Institutional Distance" (especially cultural or administrative) is so high that the core business model would require a fundamental transformation rather than simple adaptation.
#
# ### Phase 2: Risk & Compliance Vetting
#
# **Step 2: Regulatory, IP, and Geopolitical Risk Audit**
# *   **Action:** Evaluate the strength of local Intellectual Property (IP) protections, calculate the "Regulatory Friction" (permits, labor laws), and assess the Political Stability Index of the target region.
# *   **Who is Responsible:** General Counsel (Legal) and Geopolitical Risk Consultants.
# *   **How we know it is complete:** A "Compliance & Risk Matrix" is produced, outlining mandatory legal requirements and assigning a risk-adjusted "Go/No-Go" score to the political environment.
# *   **When to reconsider:** If the legal audit reveals that the company’s core IP cannot be protected or if the political environment reaches a "high" instability rating (e.g., risk of expropriation or sanctions).
#
# ### Phase 3: Financial & Operational Feasibility
#
# **Step 3: Financial Modeling and Supply Chain Stress-Testing**
# *   **Action:** Develop a 5-to-10-year NPV and IRR model that includes currency volatility and "burn" rates, while simultaneously mapping the local supply chain and Logistics Performance Index (LPI).
# *   **Who is Responsible:** CFO and COO.
# *   **How we know it is complete:** Approval of a "Financial Master Plan" that shows the project meeting the internal hurdle rate and a "Logistics Blueprint" identifying tier-1 local suppliers or import routes.
# *   **When to reconsider:** If the projected Breakeven Timeline exceeds the Board's maximum risk tolerance (e.g., >7 years) or if the Logistics Performance Index suggests infrastructure cannot support current product standards.
#
# ### Phase 4: Execution Strategy & Partner Selection
#
# **Step 4: Entry Mode Determination and Partner Due Diligence**
# *   **Action:** Finalize the entry mode (Joint Venture, Acquisition, or Greenfield FDI) and conduct deep-dive due diligence on potential local partners or site locations.
# *   **Who is Responsible:** Head of Business Development and Local Government Liaisons.
# *   **How we know it is complete:** A "Partner/Site Selection Dossier" is finalized, including a Letter of Intent (LOI) for a JV or a specific real estate/subsidiary setup plan.
# *   **When to reconsider:** If due diligence reveals ethical/reputational red flags with local partners or if the cost of high-commitment entry (FDI) has increased significantly due to interest rate shifts.
#
# ### Phase 5: Adaptation & Resource Planning
#
# **Step 5: Localization Roadmap and Human Capital Audit**
# *   **Action:** Determine the necessary product modifications (localization) and assess the "Human Capital Pipeline"—balancing the use of expatriates vs. hiring local management.
# *   **Who is Responsible:** Chief Marketing Officer (CMO) and CHRO.
# *   **How we know it is complete:** A "Localization & Talent Strategy" is presented, including a recruitment timeline for the local leadership team and a finalized product spec for the target market.
# *   **When to reconsider:** If the cost of product localization (R&D) destroys the margins projected in Phase 3, or if there is a critical shortage of local management talent capable of bridging the "cultural distance."
#
# ### Final Synthesis
# The process concludes with the **Executive Expansion Memo**, which synthesizes the outputs of all five steps for the Board of Directors to make the final "Go/No-Go" decision.

# %%
#Stage 1 - test case 3
client = genai.Client(api_key=api_key)

PREAMBLE = "Your goal is to identify ambiguity in problem statements."
LAST = "For each ambiguity, quote the unclear term, explain why it matters, and suggest a clarifying question"

response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Identify the ambiguities in the following problem:
    How should a university determine whether to modify its grading system?""",LAST]
)

print(response.text)
stage1response = response.text
# Out:
# To identify the best path forward, we must clarify the following ambiguities in the problem statement: "How should a university determine whether to modify its grading system?"
#
# ### 1. "Modify"
# *   **Why it matters:** The word "modify" is highly broad. It could range from a minor technical tweak (e.g., adding "minus" grades to an existing A-B-C scale) to a fundamental pedagogical shift (e.g., moving from a 4.0 GPA scale to a narrative-based or Pass/Fail system). The criteria for making a small change are much lower than the criteria for a total overhaul.
# *   **Clarifying Question:** Does "modify" refer to adjusting the existing scale, or is the university considering a complete transition to a different assessment philosophy, such as ungrading or competency-based grading?
#
# ### 2. "Grading system"
# *   **Why it matters:** It is unclear if this refers to the **output** (the final letter grade on a transcript), the **process** (how individual professors calculate points), or the **policy** (grading on a curve versus absolute standards). Furthermore, it is unclear if this applies to all departments equally; for example, a medical school’s grading needs differ significantly from a fine arts department’s needs.
# *   **Clarifying Question:** Does "grading system" refer to the university-wide GPA calculation policy, or the specific methods and rubrics used by faculty to assess student work?
#
# ### 3. "Determine"
# *   **Why it matters:** This term refers to the decision-making process. "Determining" could involve a top-down mandate from the administration, a democratic vote by the faculty senate, or a data-driven approach based on student performance metrics and post-graduation employment rates. The "how" depends entirely on who holds the power to decide.
# *   **Clarifying Question:** Who are the primary stakeholders in this determination process, and what weight will be given to student feedback versus faculty consensus or administrative goals?
#
# ### 4. "University"
# *   **Why it matters:** Different types of institutions have different missions. A prestigious private research university may prioritize "prestige" and avoiding grade inflation to satisfy graduate school recruiters, whereas a community college or vocational university may prioritize "accessibility" and student retention.
# *   **Clarifying Question:** What is the specific mission or tier of the university in question, and what are its primary institutional goals (e.g., academic rigor, equity, or student placement)?
#
# ### 5. "Whether"
# *   **Why it matters:** The word "whether" suggests there is a catalyst for this change, but it isn't stated. Is the university responding to a specific problem (like a mental health crisis among students or complaints from employers) or is it a routine review? The "how" of the determination depends on the problem the university is trying to solve.
# *   **Clarifying Question:** What is the specific problem or "pain point" that has prompted the university to reconsider its current system?

# %%
#Stage 2 - test case 3
client = genai.Client(api_key=api_key)

PREAMBLE = """Your goal is to use given identified ambiguity generate assumptions.
              Here is the current problem statement: How should a university determine whether to modify its grading system?"""
LAST = """For each assumption, state it clearly, explain why it is reasonable,
          and describe what changes if it is false"""

response2 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , "Identify assumptions given the following ambiguity found: ",stage1response,LAST]
)

print(response2.text)
stage2response = response2.text
# Out:
# Based on the identified ambiguities, here are five assumptions that provide a specific context for the problem: "How should a university determine whether to modify its grading system?"
#
# ---
#
# ### Assumption 1: The modification involves a fundamental shift in assessment philosophy (e.g., moving to Pass/Fail or "Ungrading").
#
# *   **Why it is reasonable:** The prompt asks how a university should "determine" a change, implying a significant decision-making process. Minor technical tweaks (like changing a 4.0 to a 4.3 scale) usually follow established administrative protocols, whereas a shift to a non-traditional system requires the deep institutional reflection suggested by the question.
# *   **What changes if it is false:** If the modification is merely a minor adjustment to grade weights or the addition of plus/minus signs, the "determination" process becomes much simpler, focusing on data modeling and technical implementation rather than pedagogical debate and philosophical alignment.
#
# ### Assumption 2: "Grading system" refers to the final transcript output (the GPA calculation policy).
#
# *   **Why it is reasonable:** While "grading" happens in the classroom, a "university" usually manages the system at the macro level—the way those grades are recorded and reported to external stakeholders (employers, grad schools). Standardizing classroom-level rubrics across all disciplines is often seen as an infringement on academic freedom.
# *   **What changes if it is false:** If "grading system" refers to the internal methods professors use to assess work (e.g., requiring all faculty to use labor-based grading), the determination process must focus on faculty training, academic freedom, and disciplinary differences rather than registrar-level policy.
#
# ### Assumption 3: The "determination" will be made through a shared governance model.
#
# *   **Why it is reasonable:** In most accredited higher education institutions, major changes to academic policy require a collaboration between the Faculty Senate (who own the curriculum) and the Administration (who handle logistics and institutional strategy).
# *   **What changes if it is false:** If the decision is a top-down mandate from a Board of Trustees or a President, the process would prioritize marketability, institutional prestige, and financial efficiency. If it were a purely student-driven democratic process, the focus would likely shift to equity, stress reduction, and grade transparency.
#
# ### Assumption 4: The university is a traditional, multi-disciplinary research institution.
#
# *   **Why it is reasonable:** This type of institution faces the most complexity in grading. It must balance the needs of disparate departments (e.g., Engineering, where grades are often curved for rigor, vs. Fine Arts, where grades may be more subjective/qualitative).
# *   **What changes if it is false:** If the institution is a specialized vocational school or a community college, the determination would be based almost entirely on workforce readiness and certificate completion rates rather than academic theory or graduate school placement.
#
# ### Assumption 5: The primary catalyst for change (the "whether") is a concern for student equity and mental health.
#
# *   **Why it is reasonable:** This is currently the most common reason universities are revisiting grading policies. Moving away from "high-stakes" grading is a trend driven by data showing that traditional grading can disadvantage underrepresented groups and contribute to student burnout.
# *   **What changes if it is false:** If the catalyst is actually "grade inflation" (the concern that grades are becoming too high and losing meaning), the determination process would focus on "rigor" and "standardization," likely resulting in more restrictive policies rather than more flexible ones.

# %%
#Stage 3 - test case 3
client = genai.Client(api_key=api_key)

PREAMBLE = """You are an expert in problem decomposition. Given the problem and assumptions below,
              produce a decomposition that would apply to THIS problem."""
problem = "How should a university determine whether to modify its grading system?"

response3 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """First, provide 5 domains which cover the problem.
                              For each domain, define the objective, identify evaluation criteria,
                              identify stakeholders, and identify dependencies""",problem,stage2response]
)

print(response3.text)
stage3response = response3.text
# Out:
# To determine whether a university should modify its grading system—specifically shifting toward a non-traditional model (Pass/Fail or Ungrading) for transcript output within a shared governance framework—the problem can be decomposed into the following five domains:
#
# ### 1. Pedagogical Integrity and Learning Outcomes
# **Objective:** To evaluate if the proposed grading modification aligns with the university’s mission of academic excellence and actually improves the quality of learning.
# *   **Evaluation Criteria:** Correlation between the new system and mastery of course material; impact on student intrinsic motivation vs. extrinsic "grade chasing"; faculty's ability to provide meaningful feedback; maintenance of rigor across diverse disciplines (e.g., STEM vs. Humanities).
# *   **Stakeholders:** Faculty Senate, Department Chairs, Curriculum Committees, Center for Teaching and Learning.
# *   **Dependencies:** Academic freedom policies; availability of discipline-specific research on "ungrading"; faculty workload capacity for qualitative assessment.
#
# ### 2. Student Equity and Holistic Well-being
# **Objective:** To assess how the change addresses systemic disparities and the mental health crisis among the student body.
# *   **Evaluation Criteria:** Statistical reduction in the "achievement gap" for underrepresented groups; measurable changes in student stress and burnout levels; impact on students with disabilities or neurodivergence who may struggle with traditional testing.
# *   **Stakeholders:** Student Government Association (SGA), Office of Equity and Inclusion, University Counseling Services, Dean of Students.
# *   **Dependencies:** Long-term internal data on student demographics and performance; psychological surveys; financial aid eligibility rules (which often require a GPA).
#
# ### 3. External Competitiveness and Post-Graduate Pathways
# **Objective:** To ensure that a shift in transcript reporting does not disadvantage students when applying for jobs, medical school, law school, or graduate programs.
# *   **Evaluation Criteria:** Acceptance rates of alumni into prestigious graduate programs under the new system; feedback from major corporate recruiters; alignment with professional licensing board requirements (e.g., ABET, ABA).
# *   **Stakeholders:** Career Services, Alumni Association, Graduate School Admissions Offices at peer institutions, Professional Accrediting Bodies.
# *   **Dependencies:** External admissions policies (e.g., how AMCAS or LSAC recalculate Pass/Fail grades); market perception of the university’s "brand" and rigor.
#
# ### 4. Administrative and Technical Infrastructure
# **Objective:** To determine the logistical feasibility of implementing a fundamental change to the GPA and transcript calculation system.
# *   **Evaluation Criteria:** Capability of existing Student Information Systems (SIS) to handle non-numerical records; cost of software reconfiguration; legal compliance with FERPA and accreditation standards.
# *   **Stakeholders:** University Registrar, Information Technology (IT) Department, Office of Legal Counsel, Bursar’s Office.
# *   **Dependencies:** Regional accreditation cycles (e.g., SACSCOC or HLC); software vendor limitations (e.g., Banner, Workday, or PeopleSoft); state and federal reporting requirements.
#
# ### 5. Institutional Strategy and Shared Governance
# **Objective:** To build consensus among the university’s diverse governing bodies and ensure the change supports the institution's long-term strategic goals.
# *   **Evaluation Criteria:** Level of consensus achieved between the Faculty Senate and the Administration; impact on student retention and graduation rates; donor and board sentiment regarding institutional "prestige."
# *   **Stakeholders:** University President, Provost, Board of Trustees, Office of Institutional Research, Major Donors.
# *   **Dependencies:** The university’s strategic plan; peer institution benchmarking (what are other R1 universities doing?); bylaws governing policy changes.

# %%
#Stage 4 - test case 3
client = genai.Client(api_key=api_key)

PREAMBLE = "You are a synthesizer, turning a problem breakdown over multiple steps into concrete action plans"
problem = "How should a university determine whether to modify its grading system?"

response4 = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = [PREAMBLE , """Using the information given, create a sequential action plan.
                              For each step, include: the action, who is responsible, how we know it is complete,
                              and when to reconsider. Do not make a final decision, just structure the process.""",
                              "Here is the problem:", problem, "Here are the assumptions:", stage2response,"Here are the domains:"
                              ,stage3response]
)

print(response4.text)
stage4response = response4.text
# Out:
# This action plan outlines the sequential steps required for a multi-disciplinary research university to determine whether to transition its grading system to a non-traditional model (e.g., Pass/Fail or Ungrading), centered on equity and shared governance.
#
# ### Phase 1: Initiation and Data Collection
#
# **Step 1: Form a Cross-Functional "Grading Philosophy Task Force"**
# *   **Action:** Appoint a committee comprising Faculty Senate representatives, Student Government leaders, the Registrar, and DEI (Diversity, Equity, and Inclusion) officers to lead the inquiry.
# *   **Responsibility:** University Provost.
# *   **How we know it is complete:** A formal charter is signed, and a meeting schedule is established with representatives from all five identified domains.
# *   **When to reconsider:** If key stakeholder groups (e.g., the Faculty Senate) refuse to appoint representatives, indicating a lack of "buy-in" for the shared governance model.
#
# **Step 2: Conduct an Internal Equity and Wellness Audit**
# *   **Action:** Analyze historical institutional data to identify achievement gaps across demographics and conduct a university-wide survey on student burnout and the psychological impact of GPA-chasing.
# *   **Responsibility:** Office of Institutional Research and University Counseling Services.
# *   **How we know it is complete:** A comprehensive report is published detailing the correlation (or lack thereof) between the current grading system and student well-being/equity.
# *   **When to reconsider:** If initial data suggests that grading is not a significant factor in student stress or inequity compared to other variables (e.g., tuition costs or housing).
#
# ### Phase 2: External and Technical Feasibility
#
# **Step 3: Perform an External Impact and "Post-Graduate Pathway" Analysis**
# *   **Action:** Survey major corporate recruiters, medical/law school admissions boards, and peer R1 institutions to determine how they would evaluate transcripts with non-traditional grading.
# *   **Responsibility:** Career Services and Dean of Graduate Admissions.
# *   **How we know it is complete:** A "Market Readiness Report" is delivered, outlining potential risks to student competitiveness in the labor and graduate markets.
# *   **When to reconsider:** If a majority of professional accrediting bodies (e.g., ABET or ABA) indicate that non-traditional grades would jeopardize program accreditation.
#
# **Step 4: Conduct a Technical and Regulatory Infrastructure Audit**
# *   **Action:** Evaluate the Student Information System (SIS) for its ability to calculate and display non-numerical transcripts and review federal/state financial aid and FERPA compliance.
# *   **Responsibility:** University Registrar and Chief Information Officer (CIO).
# *   **How we know it is complete:** A technical feasibility memo is produced, including cost estimates for software reconfiguration and a legal compliance sign-off.
# *   **When to reconsider:** If the cost of technical overhaul exceeds the available strategic budget or if federal financial aid (Title IV) requires a GPA-based "Satisfactory Academic Progress" (SAP) metric that cannot be bypassed.
#
# ### Phase 3: Synthesis and Deliberation
#
# **Step 5: Develop Pedagogical Frameworks and Disciplinary "Pilot" Models**
# *   **Action:** Create mock-up rubrics and assessment standards that maintain "rigor" in a non-traditional system, specifically addressing differences between STEM and Humanities.
# *   **Responsibility:** Center for Teaching and Learning (CTL) and Faculty Senate Curriculum Committee.
# *   **How we know it is complete:** A draft "Grading Handbook" is created that defines what "Mastery" or "Pass" looks like across disparate departments.
# *   **When to reconsider:** If department chairs from high-stakes disciplines (e.g., Engineering or Nursing) reach a deadlock on how to ensure "rigor" without numerical grades.
#
# **Step 6: Facilitate Shared Governance Town Halls and Listening Sessions**
# *   **Action:** Present the findings from the first five steps to the broader university community to gather qualitative feedback and address concerns.
# *   **Responsibility:** Faculty Senate President and Dean of Students.
# *   **How we know it is complete:** A "Stakeholder Feedback Synthesis" document is presented to the Board of Trustees and the President.
# *   **When to reconsider:** If there is overwhelming faculty or donor opposition that threatens the stability of the institutional leadership.
#
# ### Phase 4: Final Recommendation
#
# **Step 7: Final Report and Governance Vote**
# *   **Action:** Based on all collected data, the Task Force submits a formal recommendation (Modify, Status Quo, or Hybrid) for a vote by the Faculty Senate and approval by the Board of Trustees.
# *   **Responsibility:** Task Force Chair.
# *   **How we know it is complete:** An official policy decision is recorded in the minutes of the Faculty Senate and the Board of Trustees.
# *   **When to reconsider:** If the decision is delayed by a lack of a quorum or if new external mandates (e.g., state legislative changes regarding university standards) emerge during the voting period.
